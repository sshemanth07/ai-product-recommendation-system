# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached streamlit-1.57.0-py3-none-any.whl.metadata (9.6 kB)
# ...
#   Using cached torchaudio-2.11.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# ...
#   Using cached clearml-2.1.7-py2.py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached orderedmultidict-1.0.2-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
# Using cached streamlit-1.57.0-py3-none-any.whl (9.2 MB)
# Using cached pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached torchaudio-2.11.0-cp312-cp312-manylinux_2_28_x86_64.whl (1.8 MB)
# Using cached clearml-2.1.7-py2.py3-none-any.whl (1.4 MB)
# Using cached furl-2.1.4-py2.py3-none-any.whl (27 kB)
# ...

# %%
import pandas as pd
import numpy as np
import sklearn
import xgboost
import torch
import clearml

print("All required packages imported successfully.")
# Out:
# All required packages imported successfully.

# %%
import os
from clearml import Task

os.environ["CLEARML_WEB_HOST"] = "https://app.clear.ml"
os.environ["CLEARML_API_HOST"] = "https://api.clear.ml"
os.environ["CLEARML_FILES_HOST"] = "https://files.clear.ml"

os.environ["CLEARML_API_ACCESS_KEY"] = "2H0APKE3NPXU73G7H7JWN8FE0RFQB9"
os.environ["CLEARML_API_SECRET_KEY"] = "VGIwK9zLT0SpBAL_O5DwGmCUHb1lh3OGEDdkKVQd-cxFT1JtBLx6NWr6T_KIxxgWljY"

task = Task.init(
    project_name="AI-Based Product Recommendation System",
    task_name="Sprint 3 - Final Model Training",
    tags=["Sprint 3", "SageMaker", "MLOps", "Recommendation System"]
)

logger = task.get_logger()

print("ClearML connected.")
print(task.get_output_log_web_page())
# Out:
# ClearML Task: created new task id=3cb1c6dd6cb3484c971a85eaed23d520
# 2026-05-21 15:13:52,741 - clearml.Task - INFO - Storing jupyter notebook directly as code
# 2026-05-21 15:13:52,746 - clearml.Repository Detection - WARNING - Can't get url information for git repo in /home/sagemaker-user
# 2026-05-21 15:13:56.425879: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-21 15:13:56.598653: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python clearml_pipeline.py
# Out:
# 2026-05-21 15:14:20.816664: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-21 15:14:20.830398: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779376460.849354     763 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779376460.855025     763 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train_xgb_hpo_base.py
# Out:
# 2026-05-21 15:30:24.120223: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-21 15:30:24.133821: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779377424.151864    1605 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779377424.157472    1605 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python hpo_controller.py
# Out:
# 2026-05-21 15:37:26.767411: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-21 15:37:26.781123: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779377846.799894    1983 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779377846.805517    1983 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
