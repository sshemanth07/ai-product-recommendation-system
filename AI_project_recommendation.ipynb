# %% [markdown]
# <a href="https://colab.research.google.com/github/SallumAlsallum/ai-product-recommendation-system/blob/main/AI_project_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
